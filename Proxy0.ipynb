# %%
#imports and definitions
import time
import pandas as pd
import requests
from random import randint
from bs4 import BeautifulSoup
from IPython.display import Markdown, display

def proxy_anonymity_test(proxy):
    #uses http://proxydb.net/anon
    #proxy must be exactly in this form: {'http': 'http://Logmech:AlphaBetaGamma@86.105.96.1:60099'}
    with requests.Session() as session:
        session.proxies.update(proxy)
        session.headers.update(headers)
        proxydb_html_page = session.get('http://proxydb.net/anon').content
    soup = BeautifulSoup(proxydb_html_page, 'html.parser')
    tags = soup.find('dl', class_='row').find_all('dd')
    ip = tags[0].text
    anonymity_level = tags[1].text
    country = tags[2].find('img')['alt']
    city = tags[3].text
    region = tags[4].text
    isp = tags[5].text
    printmd("**Proxy Anonymity Test Results:**")
    print("IP: " + ip)
    print("ANONYMITY-LEVEL: " + anonymity_level)
    print("COUNTRY: " + country)
    print("CITY: " + city)
    print("REGION: " + region)
    print("ISP: " + isp)
    printmd("**HTTP-Request Headers:**")
    tag = soup.find('pre')
    print(tag.text)
#----------------------------------------------------------------------------------------------------------------------------------

#Getter functions
#Returns the info on a listing page and also fills the dataframe's corresponding slots
def get_rooms_bedrooms_and_bathrooms(df, row_index, listing_page):
    #gets the number of rooms, bedrooms and bathrooms, if they are not specified returns None
    #returns a dictionary
    
    # rooms
    try:
        number_of_rooms = listing_page.find('div', class_='row teaser').find(class_="col-lg-3 col-sm-6 piece").text.strip()
    except AttributeError:
        number_of_rooms = None
    
    #bedrooms
    try :
        number_of_bedrooms = listing_page.find('div', class_='row teaser').find(class_="col-lg-3 col-sm-6 cac").text.strip()
    except AttributeError:
        number_of_bedrooms = None
        
    #bathrooms
    try:
        number_of_bathrooms = listing_page.find('div', class_='row teaser').find(class_="col-lg-3 col-sm-6 sdb").text.strip()
    except AttributeError:
        number_of_bathrooms = None
    
    df.loc[row_index, ['Rooms', 'Bedrooms', 'Bathrooms']] = [number_of_rooms, number_of_bedrooms, number_of_bathrooms]
    
    return {'Rooms' : number_of_rooms, 'Bedrooms': number_of_bedrooms, 'Bathrooms': number_of_bathrooms}
def get_other_features(df, row_index, listing_page):
    #gets the year built, additional features, pot gross revenue and zoning of listing, and three different types of areas.
    #Null if not specified returns a dict where the keys are the feature names and values are the feature values
    other_features = {}
    for feature_name in ['Year built', 'Additional features', 'Potential gross revenue', 'Zoning', 'Lot area', 'Use of property', 'Available area', 'Building area (at ground level)']:
        try:
            feature = listing_page.find('div', class_='carac-title', text=feature_name).next_sibling.next_sibling.text
        except AttributeError:
            feature = None
        df.loc[row_index, feature_name] = feature
        other_features[feature_name] = feature
    return other_features
def get_description(df, row_index, listing_page):
    try:
        description = listing_page.find('div', itemprop='description').text.strip()
    except AttributeError:
        description = None
    df.loc[row_index, 'Description'] = description
    return description
#----------------------------------------------------------------------------------------------------------------------------------

#Uses the given proxy to complete the given dataframe by calling the getter functions defined above
#Returns the completed dataframe and prints all the info's returned by the getter functions
def complete_df(df, proxy=None):
    with requests.Session() as session:
        if proxy is not None:
            session.proxies.update(proxy)
        session.headers.update({'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36'})
        print('Proxy: {}'.format(proxy))
        
        for row_index in df.index:
            listing_page = BeautifulSoup(session.get(df.loc[row_index, 'URL']).text, 'html.parser')
            
            print("\tRow: {}".format(row_index))
            
            #get the data and print it
            #rooms, bedrooms, bathrooms
            print('''\t\tNumber of rooms: {Rooms}
            \tNumber of bedrooms: {Bedrooms}
            \tNumber of bathrooms: {Bathrooms}'''.format(**get_rooms_bedrooms_and_bathrooms(df, row_index, listing_page)))
            
            #other_features
            print('''\t\tYear built: {Year built}
            \tPotential gross revenue: {Potential gross revenue}
            \tZoning: {Zoning}
            \tAdditional features: {Additional features}
            \tUse of property: {Use of property}
            \tBuilding area (at ground level): {Building area (at ground level)}
            \tAvailable area: {Available area}
            \tLot area: {Lot area}'''.format(**get_other_features(df, row_index, listing_page)))
            
            #description
            print("\n\t\tDescription: {}".format(get_description(df, row_index, listing_page)))  
            print("\n")
            time.sleep(randint(7,9))
    return df
#---------------------------------------------------------------------------------------------------------------------------------

#retreive the partition of the dataframe and the proxies 
# %store -r partition_of_incomplete_df proxies
print(proxies[0])
partition_of_incomplete_df[0]
# Out:
# {'http': 'http://Logmech:AlphaBetaGamma@86.105.96.100:60099'}
#       Category      Price  PPSF      PPSM                        Street  \
# 0          Lot   280000.0   NaN       NaN           Chemin  Édouard-Roy
# 1          Lot  1695000.0   NaN       NaN    108, Chemin de Gray Valley
# 2   Hobby farm  2399000.0   NaN       NaN            21, Rang des Vents
# 3          Lot        NaN   NaN  399900.0             60, Chemin  Grant
# 4      Cottage  1749000.0   NaN       NaN       117, Chemin des Érables
# 5   Hobby farm   199000.0   NaN       NaN         30, Chemin du Portage
# 6          Lot   689000.0   NaN       NaN           Côte des Intrépides
# 7         Land   650000.0   NaN       NaN         Chemin  Saint-Cyr Sud
# 8         Land  3200000.0   NaN       NaN                    Route  148
# 9         Land   139000.0   NaN       NaN         Chemin  Owl's Landing
# 10  Hobby farm   749000.0   NaN       NaN          205Z, Chemin  Brochu
# 11         Lot   250000.0   NaN       NaN          Chemin de la Martine
# 12        Land   324900.0   NaN       NaN                 2200, 6e Rang
# 13        Land  1400000.0   NaN       NaN                Lac à la Carpe
# 14         Lot  3250000.0   NaN       NaN          Chemin des Outaouais
# 15     Cottage   299000.0   NaN       NaN             1091Z, Route  263
# 16         Lot   349900.0   NaN       NaN             Chemin de l'Eider
# 17     Cottage   794000.0   NaN       NaN        1521Z, Chemin des Pins
# 18        Land  1500000.0   NaN       NaN                 Montée  Brien
# 19         Lot   350000.0   NaN       NaN              Route du Village
# 20         Lot  1125000.0   NaN       NaN          Chemin du Lac-Macaza
# 21        Land   895000.0   NaN       NaN     Chemin des 5e-et-6e-Rangs
# 22        Land   649000.0   NaN       NaN                       4e Rang
# 23        Land   599000.0   NaN       NaN          351, Route  Rousseau
# 24        Land   499000.0   NaN       NaN                       9e Rang
# 25         Lot   699000.0   NaN       NaN                        Rang 2
# 26  Hobby farm  2495000.0   NaN       NaN     2 - 9, Chemin de la Forge
# 27        Land  1200000.0   NaN       NaN          Rue  Olivier-Guimond
# 28         Lot   125000.0   NaN       NaN         Chemin du Lac-Francis
# 29  Hobby farm  1100000.0   NaN       NaN        2050, Chemin  Hamilton
# 30         Lot  3599000.0   NaN       NaN        Route  Jacques-Cartier
# 31        Land   130000.0   NaN       NaN            Chemin du Lac-Long
# 32        Land   160000.0   NaN       NaN            Chemin du Lac-Long
# 33        Land   300000.0   NaN       NaN             Chemin du 7e-Rang
# 34         Lot  1250000.0   NaN       NaN      Rue  Antoinette-Charland
# 35         Lot  1195000.0   NaN       NaN                Rue du Domaine
# 36  Hobby farm   789000.0   NaN       NaN         26Z, Chemin  Loiselle
# 37  Hobby farm   899000.0   NaN       NaN  284, Chemin  Cyrille-Beaudry
# 38         Lot   495000.0   NaN       NaN                   Rue  Bigras
#
#                                                  City  \
# 0   Sherbrooke (Brompton/Rock Forest/Saint-Élie/De...
# 1                                           Huberdeau
# 2                                             Brébeuf
# 3                                           Bouchette
# 4                                        Frelighsburg
# 5                                        Rivière-Héva
# 6                                      Mont-Tremblant
# 7                                      Wentworth-Nord
# 8                                           Grenville
# 9                               L'Isle-aux-Allumettes
# 10                                    Cookshire-Eaton
# 11                      Petite-Rivière-Saint-François
# 12                                      Saint-Calixte
# 13                                       Mont-Laurier
# 14                                     Pointe-Fortune
# 15                           Sainte-Cécile-de-Whitton
# 16                            Saint-Faustin/Lac-Carré
# 17                                     Trois-Rivières
# 18                                      Lac-Supérieur
# 19                                     Rapide-Danseur
# 20                                          La Macaza
# 21                                         Lac-Saguay
# 22                                       Saint-Damien
# 23                            Notre-Dame-de-Montauban
# 24                                         Saint-Côme
# 25                                          Lac-Simon
# 26                                              Ripon
# 27                                     Pointe-Fortune
# 28                             Notre-Dame-de-Pontmain
# 29                                          Inverness
# 30                                          Sept-Îles
# 31                                           Blue Sea
# 32                                           Blue Sea
# 33                                          La Macaza
# 34                                     Wentworth-Nord
# 35                                     Wentworth-Nord
# 36                                           Westbury
# 37                                         Saint-Paul
# 38                                 Brownsburg-Chatham
#
#                                                   URL  Rooms  Bedrooms  \
# 0   https://www.centris.ca/en/lots~for-sale~sherbr...    NaN       NaN
# 1   https://www.centris.ca/en/lots~for-sale~huberd...    NaN       NaN
# 2   https://www.centris.ca/en/hobby-farms~for-sale...    NaN       NaN
# 3   https://www.centris.ca/en/lots~for-sale~bouche...    NaN       NaN
# 4   https://www.centris.ca/en/cottages~for-sale~fr...    NaN       NaN
# 5   https://www.centris.ca/en/hobby-farms~for-sale...    NaN       NaN
# 6   https://www.centris.ca/en/lots~for-sale~mont-t...    NaN       NaN
# 7   https://www.centris.ca/en/land~for-sale~wentwo...    NaN       NaN
# 8   https://www.centris.ca/en/land~for-sale~grenvi...    NaN       NaN
# 9   https://www.centris.ca/en/land~for-sale~l-isle...    NaN       NaN
# 10  https://www.centris.ca/en/hobby-farms~for-sale...    NaN       NaN
# 11  https://www.centris.ca/en/lots~for-sale~petite...    NaN       NaN
# 12  https://www.centris.ca/en/land~for-sale~saint-...    NaN       NaN
# 13  https://www.centris.ca/en/land~for-sale~mont-l...    NaN       NaN
# 14  https://www.centris.ca/en/lots~for-sale~pointe...    NaN       NaN
# 15  https://www.centris.ca/en/cottages~for-sale~sa...    NaN       NaN
# 16  https://www.centris.ca/en/lots~for-sale~saint-...    NaN       NaN
# 17  https://www.centris.ca/en/cottages~for-sale~tr...    NaN       NaN
# 18  https://www.centris.ca/en/land~for-sale~lac-su...    NaN       NaN
# 19  https://www.centris.ca/en/lots~for-sale~rapide...    NaN       NaN
# 20  https://www.centris.ca/en/lots~for-sale~la-mac...    NaN       NaN
# 21  https://www.centris.ca/en/land~for-sale~lac-sa...    NaN       NaN
# 22  https://www.centris.ca/en/land~for-sale~saint-...    NaN       NaN
# 23  https://www.centris.ca/en/land~for-sale~notre-...    NaN       NaN
# 24  https://www.centris.ca/en/land~for-sale~saint-...    NaN       NaN
# 25  https://www.centris.ca/en/lots~for-sale~lac-si...    NaN       NaN
# 26  https://www.centris.ca/en/hobby-farms~for-sale...    NaN       NaN
# 27  https://www.centris.ca/en/land~for-sale~pointe...    NaN       NaN
# 28  https://www.centris.ca/en/lots~for-sale~notre-...    NaN       NaN
# 29  https://www.centris.ca/en/hobby-farms~for-sale...    NaN       NaN
# 30  https://www.centris.ca/en/lots~for-sale~sept-i...    NaN       NaN
# 31  https://www.centris.ca/en/land~for-sale~blue-s...    NaN       NaN
# 32  https://www.centris.ca/en/land~for-sale~blue-s...    NaN       NaN
# 33  https://www.centris.ca/en/land~for-sale~la-mac...    NaN       NaN
# 34  https://www.centris.ca/en/lots~for-sale~wentwo...    NaN       NaN
# 35  https://www.centris.ca/en/lots~for-sale~wentwo...    NaN       NaN
# 36  https://www.centris.ca/en/hobby-farms~for-sale...    NaN       NaN
# 37  https://www.centris.ca/en/hobby-farms~for-sale...    NaN       NaN
# 38  https://www.centris.ca/en/lots~for-sale~browns...    NaN       NaN
#
#     Bathrooms  Lot area  Year built  Additional features  \
# 0         NaN       NaN         NaN                  NaN
# 1         NaN       NaN         NaN                  NaN
# 2         NaN       NaN         NaN                  NaN
# 3         NaN       NaN         NaN                  NaN
# 4         NaN       NaN         NaN                  NaN
# 5         NaN       NaN         NaN                  NaN
# 6         NaN       NaN         NaN                  NaN
# 7         NaN       NaN         NaN                  NaN
# 8         NaN       NaN         NaN                  NaN
# 9         NaN       NaN         NaN                  NaN
# 10        NaN       NaN         NaN                  NaN
# 11        NaN       NaN         NaN                  NaN
# 12        NaN       NaN         NaN                  NaN
# 13        NaN       NaN         NaN                  NaN
# 14        NaN       NaN         NaN                  NaN
# 15        NaN       NaN         NaN                  NaN
# 16        NaN       NaN         NaN                  NaN
# 17        NaN       NaN         NaN                  NaN
# 18        NaN       NaN         NaN                  NaN
# 19        NaN       NaN         NaN                  NaN
# 20        NaN       NaN         NaN                  NaN
# 21        NaN       NaN         NaN                  NaN
# 22        NaN       NaN         NaN                  NaN
# 23        NaN       NaN         NaN                  NaN
# 24        NaN       NaN         NaN                  NaN
# 25        NaN       NaN         NaN                  NaN
# 26        NaN       NaN         NaN                  NaN
# 27        NaN       NaN         NaN                  NaN
# 28        NaN       NaN         NaN                  NaN
# 29        NaN       NaN         NaN                  NaN
# 30        NaN       NaN         NaN                  NaN
# 31        NaN       NaN         NaN                  NaN
# 32        NaN       NaN         NaN                  NaN
# 33        NaN       NaN         NaN                  NaN
# 34        NaN       NaN         NaN                  NaN
# 35        NaN       NaN         NaN                  NaN
# 36        NaN       NaN         NaN                  NaN
# 37        NaN       NaN         NaN                  NaN
# 38        NaN       NaN         NaN                  NaN
#
#     Potential gross revenue  Zoning  Description  Use of property  \
# 0                       NaN     NaN          NaN              NaN
# 1                       NaN     NaN          NaN              NaN
# 2                       NaN     NaN          NaN              NaN
# 3                       NaN     NaN          NaN              NaN
# 4                       NaN     NaN          NaN              NaN
# 5                       NaN     NaN          NaN              NaN
# 6                       NaN     NaN          NaN              NaN
# 7                       NaN     NaN          NaN              NaN
# 8                       NaN     NaN          NaN              NaN
# 9                       NaN     NaN          NaN              NaN
# 10                      NaN     NaN          NaN              NaN
# 11                      NaN     NaN          NaN              NaN
# 12                      NaN     NaN          NaN              NaN
# 13                      NaN     NaN          NaN              NaN
# 14                      NaN     NaN          NaN              NaN
# 15                      NaN     NaN          NaN              NaN
# 16                      NaN     NaN          NaN              NaN
# 17                      NaN     NaN          NaN              NaN
# 18                      NaN     NaN          NaN              NaN
# 19                      NaN     NaN          NaN              NaN
# 20                      NaN     NaN          NaN              NaN
# 21                      NaN     NaN          NaN              NaN
# 22                      NaN     NaN          NaN              NaN
# 23                      NaN     NaN          NaN              NaN
# 24                      NaN     NaN          NaN              NaN
# 25                      NaN     NaN          NaN              NaN
# 26                      NaN     NaN          NaN              NaN
# 27                      NaN     NaN          NaN              NaN
# 28                      NaN     NaN          NaN              NaN
# 29                      NaN     NaN          NaN              NaN
# 30                      NaN     NaN          NaN              NaN
# 31                      NaN     NaN          NaN              NaN
# 32                      NaN     NaN          NaN              NaN
# 33                      NaN     NaN          NaN              NaN
# 34                      NaN     NaN          NaN              NaN
# 35                      NaN     NaN          NaN              NaN
# 36                      NaN     NaN          NaN              NaN
# 37                      NaN     NaN          NaN              NaN
# 38                      NaN     NaN          NaN              NaN
#
#     Available area  Building area (at ground level)
# 0              NaN                              NaN
# 1              NaN                              NaN
# 2              NaN                              NaN
# 3              NaN                              NaN
# 4              NaN                              NaN
# 5              NaN                              NaN
# 6              NaN                              NaN
# 7              NaN                              NaN
# 8              NaN                              NaN
# 9              NaN                              NaN
# 10             NaN                              NaN
# 11             NaN                              NaN
# 12             NaN                              NaN
# 13             NaN                              NaN
# 14             NaN                              NaN
# 15             NaN                              NaN
# 16             NaN                              NaN
# 17             NaN                              NaN
# 18             NaN                              NaN
# 19             NaN                              NaN
# 20             NaN                              NaN
# 21             NaN                              NaN
# 22             NaN                              NaN
# 23             NaN                              NaN
# 24             NaN                              NaN
# 25             NaN                              NaN
# 26             NaN                              NaN
# 27             NaN                              NaN
# 28             NaN                              NaN
# 29             NaN                              NaN
# 30             NaN                              NaN
# 31             NaN                              NaN
# 32             NaN                              NaN
# 33             NaN                              NaN
# 34             NaN                              NaN
# 35             NaN                              NaN
# 36             NaN                              NaN
# 37             NaN                              NaN
# 38             NaN                              NaN

# %%
#complete the slice of the dataframe with the proxy with the same position in the list and store the completed slice
df0 = complete_df(partition_of_incomplete_df[0], proxies[0])
# %store df0
df0
# Out:
# Proxy: {'http': 'http://Logmech:AlphaBetaGamma@86.105.96.100:60099'}
# 	Row: 0
# 		Number of rooms: None
#             	Number of bedrooms: None
#             	Number of bathrooms: None
# 		Year built: None
#             	Potential gross revenue: None
#             	Zoning: Residential
#             	Additional features: Located on a stream
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 1,873,080 sqft
#
# 		Description: Rareté ,+- 43 acres situé à quelques minutes du centre urbain ,en grande partie boisé avec ruisseau .Site idéal pour implanter son projet de rêve ou comme investisseur pour méga projet pour le futur .Voir avec courtier inscripteur pour les usages permis.
#
#
# 	Row: 1
# 		Number of rooms: None
#             	Number of bedrooms: None
#             	Number of bathrooms: None
# 		Year built: None
#             	Potential gross revenue: None
#             	Zoning: Other, Forest, Residential, Agricultural
#             	Additional features: Located on a river, Non-navigable body of water
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 8,668,431 sqft
#
# 		Description: GRAY VALLEY - Remarquable property of over 223 acres situated along the majestic "Rivière Rouge" only minutes away from the quaint village of Huberdeau. Once used as a sheep farm, this land offers many possibilities. Rolling hills, pastures and meadows allow for breathtaking views. Ideal location to create your very own family estate.
#
#
# 	Row: 2
# 		Number of rooms: 12 rooms
#             	Number of bedrooms: 3 bedrooms
#             	Number of bathrooms: 4 bathrooms
# 		Year built: Unknown age
#             	Potential gross revenue: None
#             	Zoning: None
#             	Additional features: Located on a river
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 3,907,403 sqft
#
# 		Description: Fully renovated, this unique contemporary farmhouse on more than 89 acres of land as far as the eye can see has its private sandy beach on the Red River. It's chic and luxurious decor makes this country house ideal for living and entertaining. It is an incredible private domain of conviviality.
#
#
# 	Row: 3
# 		Number of rooms: None
#             	Number of bedrooms: None
#             	Number of bathrooms: None
# 		Year built: None
#             	Potential gross revenue: None
#             	Zoning: Residential
#             	Additional features: Located on a lake, Navigable body of water
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 1,374,299 sqft
#
# 		Description: A wonderful piece of land on the majestic 31 Miles Lake and also frontage on lakes Poirier and Vaseux. Big maple trees gives it a big extra. Approximately 250 feet of frontage on lake 31 Miles and even more frontage on the other lakes. Imagine your estate on lake 31 miles and cottages for family or friends on the other lakes. Has to be seen.
#
#
# 	Row: 4
# 		Number of rooms: 13 rooms
#             	Number of bedrooms: 3 bedrooms
#             	Number of bathrooms: 2 bathrooms and 1 powder room
# 		Year built: Unknown age
#             	Potential gross revenue: None
#             	Zoning: None
#             	Additional features: Located on a pond, Non-navigable body of water
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 2,073,456 sqft
#
# 		Description: Follow your dream, Country Home. Frelighsburg +47.6 acres. The perfect domain for your projects just 1h30 min. from MONTREAL. You will not believe your eyes once in front of this panoramic VIEW of the SUTTON & JAY PEAK Mountains. Several buildings, barns and ponds. The gentleman farmer in you will be delighted. #farmhouse #easterntownships
#
#
# 	Row: 5
# 		Number of rooms: 10 rooms
#             	Number of bedrooms: 2 bedrooms
#             	Number of bathrooms: 1 bathroom
# 		Year built: 1954
#             	Potential gross revenue: None
#             	Zoning: None
#             	Additional features: Located on a river
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 6,048,135 sqft
#
# 		Description: Fermette de 138.8 acres, accès à la rivière Cadillac. Charmante maison 1 étage et demi de 2 chambres avec possibilité de 3. Céramique chauffante dans la cuisine. Petit garage 18 x 25 p et grange 36.8 x 46.9 p. Beaucoup de rénovations effectuées, d'autres encore à faire... Avoir des animaux est votre rêve? Venez visiter! À qui la chance?
#
#
# 	Row: 6
# 		Number of rooms: None
#             	Number of bedrooms: None
#             	Number of bathrooms: None
# 		Year built: None
#             	Potential gross revenue: None
#             	Zoning: Resort, Residential
#             	Additional features: Resort, Located on a lake, Navigable body of water
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 4,530,240 sqft
#
# 		Description: 104 acres. 261.58 m of frontage on the edge of the lake Duhamel. South side: Accessible at the end of Côte des Intrépides from the 117 HWY. Duhamel Lake is navigable.
#
#
# 	Row: 7
# 		Number of rooms: None
#             	Number of bedrooms: None
#             	Number of bathrooms: None
# 		Year built: None
#             	Potential gross revenue: None
#             	Zoning: Residential
#             	Additional features: Located on a lake, Non-navigable body of water
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 2,743,914 sqft
#
# 		Description: Magnificent 63-acre waterfront lot on the prestigious Lac St-Cyr with 483ft of shoreline. Build your dream home on this pristine lake which is part of the distinguished Lac St-Victor Estates. Ideally situated at the end of the road ensuring maximum privacy and tranquillity. 75mins from MTL, 15 mins to Morin Heights and just 20 mins to St.Sauveur.
#
#
# 	Row: 8
# 		Number of rooms: None
#             	Number of bedrooms: None
#             	Number of bathrooms: None
# 		Year built: None
#             	Potential gross revenue: None
#             	Zoning: Recreational and tourism, Residential
#             	Additional features: Located on a river, Navigable body of water
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 12,022,560 sqft
#
# 		Description: An exceptional 276-acre site awaits you to design the project of your dreams. A natural environment in the heart of a residential and recreational tourism sector giving way to many creative ideas. Its adjacent bodies of water such as the Ottawa River, Pumpkinseed Bay and Calumet Bay will amaze you.
#
#
# 	Row: 9
# 		Number of rooms: None
#             	Number of bedrooms: None
#             	Number of bathrooms: None
# 		Year built: None
#             	Potential gross revenue: None
#             	Zoning: Residential
#             	Additional features: Located on a river
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 3,049,200 sqft
#
# 		Description: 70 Acres with 477 Feet of Waterfront on the Ottawa
#
#
# 	Row: 10
# 		Number of rooms: 13 rooms
#             	Number of bedrooms: 4 bedrooms
#             	Number of bathrooms: 2 bathrooms
# 		Year built: Unknown age
#             	Potential gross revenue: None
#             	Zoning: None
#             	Additional features: Located on a pond, Basement 6 feet or +
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 4,198,707 sqft
#
# 		Description: Lot du terrain seulement est taxable
#
#
# 	Row: 11
# 		Number of rooms: None
#             	Number of bedrooms: None
#             	Number of bathrooms: None
# 		Year built: None
#             	Potential gross revenue: None
#             	Zoning: Commercial, Forest, Residential, Recreational and tourism
#             	Additional features: Located on a river, Non-navigable body of water
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 1,913,791 sqft
#
# 		Description: None
# 	Row: 12
# 		Number of rooms: None
#             	Number of bedrooms: None
#             	Number of bathrooms: None
# 		Year built: None
#             	Potential gross revenue: None
#             	Zoning: Residential
#             	Additional features: Located on a pond, Non-navigable body of water
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 3,354,571 sqft
#
# 		Description: « TERRE UNIQUE À SAINT-CALIXTE » 91 arpents de plein air. Verger, arbres matures abritant les animaux RÉALISEZ VOTRE PROJET en harmonie avec la nature! Étang pour ensemencer la truite. Ruisseaux et sentiers vont de pair. INTIMITÉ, à l'abri des regards. SITE PRIVÉ. Sur rendez-vous seulement. Havre de paix. À 5 minutes du village. www.st-calixte.com
#
#
# 	Row: 13
# 		Number of rooms: None
#             	Number of bedrooms: None
#             	Number of bathrooms: None
# 		Year built: None
#             	Potential gross revenue: None
#             	Zoning: Residential
#             	Additional features: Located on a lake
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 14,157,000 sqft
#
# 		Description: A absolutely amazing opportunity to create a private domain. This property of +/- 325 acres of land with its own lake is an absolute gem.
#
#
# 	Row: 14
# 		Number of rooms: None
#             	Number of bedrooms: None
#             	Number of bathrooms: None
# 		Year built: None
#             	Potential gross revenue: None
#             	Zoning: Residential
#             	Additional features: Located on a river, Navigable body of water
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 3,038,863 sqft
#
# 		Description: Four adjoining, WATERFRONT, RESIDENTIAL lands sold as one unit totalling 3,038,867 square feet. Sub-dividable in 55+ lots with current zoning. Almost halfway between Montreal and Ottawa. 1,664 ft of frontage on Outaouais river. PLEASE READ ADDENDUM
#
#
# 	Row: 15
# 		Number of rooms: 11 rooms
#             	Number of bedrooms: 3 bedrooms
#             	Number of bathrooms: 1 bathroom and 1 powder room
# 		Year built: 1908
#             	Potential gross revenue: None
#             	Zoning: None
#             	Additional features: Located on a stream, Non-navigable body of water
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 2,117,016 sqft
#
# 		Description: Belle d'époque sur une terre de 48.6 acres. Terre à bois à l'arrière avec une partie en érables, prairie, ruisseau, sentiers, pommiers, bois mature. Excellent pour la chasse. Garage détaché avec atelier isolé et espace pour cabane à sucre. *** Prix de vente selon évaluation agrée de novembre 2020 *** Voir suite addenda.
#
#
# 	Row: 16
# 		Number of rooms: None
#             	Number of bedrooms: None
#             	Number of bathrooms: None
# 		Year built: None
#             	Potential gross revenue: None
#             	Zoning: Residential
#             	Additional features: Located on a lake, Non-navigable body of water
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 1,512,344 sqft
#
# 		Description: Magnifique terrain de 34 acres (1 511 796 pieds carrés)avec environ 250 pieds sur le lac à Brissette avec sentiers pédestres et à raquette aménagés.  Vue incroyable sur le lac et les montagnes avec la possibilité d'y construire votre maison de rêve. À 5 minutes du golf Laurentien, 10 minutes du Mont-Blanc et 25 minutes de Tremblant.
#
#
# 	Row: 17
# 		Number of rooms: 3 rooms
#             	Number of bedrooms: None
#             	Number of bathrooms: None
# 		Year built: 1940
#             	Potential gross revenue: None
#             	Zoning: None
#             	Additional features: Located on a river, Basement 6 feet or +
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 5,127,931 sqft
#
# 		Description: Ce domaine comporte un terrain de 1 300 000 pi2 + une terre à bois de 4 100 000 pi2. La résidence principale possède 34 chambres et plusieurs autres pièces. 2 autres bâtisses y sont érigés + un terrain de tennis et une piscine creusée. 640 pieds de frontage à la rivière St-Maurice. À voir!
#
#
# 	Row: 18
# 		Number of rooms: None
#             	Number of bedrooms: None
#             	Number of bathrooms: None
# 		Year built: None
#             	Potential gross revenue: None
#             	Zoning: Residential
#             	Additional features: Located on a lake, Non-navigable body of water
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 14,847,671 sqft
#
# 		Description: Investors, promoters or entrepreneurs ... Great opportunity this lot is sold in one piece. Take the opportunity to acquire this little piece of paradise.
#
#
# 	Row: 19
# 		Number of rooms: None
#             	Number of bedrooms: None
#             	Number of bathrooms: None
# 		Year built: None
#             	Potential gross revenue: None
#             	Zoning: Residential, Resort
#             	Additional features: Resort, Located on a river, Navigable body of water
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 2,981,374 sqft
#
# 		Description: None
#
#
# 	Row: 20
# 		Number of rooms: None
#             	Number of bedrooms: None
#             	Number of bathrooms: None
# 		Year built: None
#             	Potential gross revenue: None
#             	Zoning: Residential
#             	Additional features: Resort, Located on a lake, Navigable body of water
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 3,179,880 sqft
#
# 		Description: WATERFRONT! Magnificent Domaine wooded on Lake Macaza. Calling all Developers! 73 acres, Shoreline +/- 4,000 linear feet (1,219 meters) Located just 30 min from Mt. Tremblant. Sublime and tranquility in a nature lovers paradise. Subdivision of 19 lots directly on the lake and sub-divison of 30 lots with lake access 49 lots total!
#
#
# 	Row: 21
# 		Number of rooms: None
#             	Number of bedrooms: None
#             	Number of bathrooms: None
# 		Year built: None
#             	Potential gross revenue: None
#             	Zoning: Residential
#             	Additional features: Located on a lake, Non-navigable body of water
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 11,604,560 sqft
#
# 		Description: Devenez propriétaire de votre coin de pays à vous seul! Magnifique domaine comme il y en a peu, offrant un oasis de paix à son propriétaire, 2 lacs de grandes superficies complètement privés avec comme voisin les terres gouvernementales, 2 superbe chalets dont un en bois rond et une érablière complètement aménagée vous y attendent!!
#
#
# 	Row: 22
# 		Number of rooms: None
#             	Number of bedrooms: None
#             	Number of bathrooms: None
# 		Year built: None
#             	Potential gross revenue: None
#             	Zoning: Residential
#             	Additional features: Located on a lake, Non-navigable body of water
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 4,443,123 sqft
#
# 		Description: Lake surrounded by crown land 1.2 km long. Lot of 100 acres subdivisible into 5 for construction on the edge of Lake Kael. Totally wild head lake 10 minutes drive from the village of Sainte-Émélie energy! A unique product extremely rare!
#
#
# 	Row: 23
# 		Number of rooms: None
#             	Number of bedrooms: None
#             	Number of bathrooms: None
# 		Year built: None
#             	Potential gross revenue: None
#             	Zoning: Residential
#             	Additional features: Resort, Located on a lake, Non-navigable body of water
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 4,592,988 sqft
#
# 		Description: Bord du lac ( privé) ce domaine de 106 acres possède son châlet rustique de 3 cac et 2 sdb avec sa grande terrasse orientée plein Sud  donnant sur une belle plage de sable et un quai pour plonger dans ses eaux limpides!Venez vous y ressourcer en famille ou entre amis ou avec vos clients à moins de 1,30 de Québec et 2,30 de Montréal.
# 	Row: 24
# 		Number of rooms: None
#             	Number of bedrooms: None
#             	Number of bathrooms: None
# 		Year built: None
#             	Potential gross revenue: None
#             	Zoning: Resort, Recreational and tourism, Residential
#             	Additional features: Located on a lake, Non-navigable body of water
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 8,108,050 sqft
#
# 		Description: Terre avec lac à vendre, rare sur le marché. Possibilité d'y faire un beau domaine.
#
#
# 	Row: 25
# 		Number of rooms: None
#             	Number of bedrooms: None
#             	Number of bathrooms: None
# 		Year built: None
#             	Potential gross revenue: None
#             	Zoning: Resort, Residential
#             	Additional features: Located on a lake, Navigable body of water
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 2,060,856 sqft
#
# 		Description: Are you looking for nature and great outdoors? This 47-acre lot with nearly 900 feet (275m) on the shores of magnificent Lac Simon will satisfy you! Whether for an investment (possible subdivision), a prestigious residence, or an intergeneration, this land offers you several possibilities with an extraordinary view of the lake!
#
#
# 	Row: 26
# 		Number of rooms: 50 rooms
#             	Number of bedrooms: 9 bedrooms (1 in basement)
#             	Number of bathrooms: 7 bathrooms and 2 powder rooms
# 		Year built: 1996
#             	Potential gross revenue: None
#             	Zoning: None
#             	Additional features: Located on a pond, Non-navigable body of water
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 21,462,883 sqft
#
# 		Description: DOMAIN of over 492 acres with 5 properties, including four 4-season residences (one with indoor pool!) And a huge garage with apartment on the 2nd floor. Several annex buildings including 1 stable with a riding arena for horses. 10 km of motorable road, maple grove 250 notches with kettle. 75 acres of meadows for cultivating.
#
#
# 	Row: 27
# 		Number of rooms: None
#             	Number of bedrooms: None
#             	Number of bathrooms: None
# 		Year built: None
#             	Potential gross revenue: None
#             	Zoning: Residential
#             	Additional features: Located on a lake
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 1,679,765 sqft
#
# 		Description: Remarkable lot to be developed. There are three lakes on the site (see all possible lots for this project).These lots are zoned unifamily. This site could be ideal for a very uncommon but profitable type of developed. A community with a common access to the lakes as well as common activities and pool etc.
#
#
# 	Row: 28
# 		Number of rooms: None
#             	Number of bedrooms: None
#             	Number of bathrooms: None
# 		Year built: None
#             	Potential gross revenue: None
#             	Zoning: Residential
#             	Additional features: Located on a lake
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 4,479,304 sqft
#
# 		Description: None
#
#
# 	Row: 29
# 		Number of rooms: 10 rooms
#             	Number of bedrooms: 4 bedrooms
#             	Number of bathrooms: 2 bathrooms
# 		Year built: Unknown age
#             	Potential gross revenue: None
#             	Zoning: None
#             	Additional features: Located on a pond, Basement 6 feet or +
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 4,859,989 sqft
#
# 		Description: Renowned strawberry and raspberry farm. Magnificent country house, pretty pond. It is a haven of peace, located near the village of Inverness. Quality land for your crops, meadows for your animals. 32 wooded acres with many maple trees. Spacious house with character, offering 4 bedrooms and 2 bathrooms.
#
#
# 	Row: 30
# 		Number of rooms: None
#             	Number of bedrooms: None
#             	Number of bathrooms: None
# 		Year built: None
#             	Potential gross revenue: None
#             	Zoning: Other, Resort, Residential, Forest
#             	Additional features: Located on a fleuve (river), Navigable body of water
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 133,104,149 sqft
#
# 		Description: 3055 acres of flat land 20 minutes away frome the city, air port and strategically located shipping Harbour.The shipping Harbour is part of the most important seaway system in North america. Sept iles lies at the enterance of the seaway were the river meets the sea. An Ideal Location.
#
#
# 	Row: 31
# 		Number of rooms: None
#             	Number of bedrooms: None
#             	Number of bathrooms: None
# 		Year built: None
#             	Potential gross revenue: None
#             	Zoning: Resort, Residential, Recreational and tourism
#             	Additional features: Located on a lake
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 3,409,301 sqft
#
# 		Description: Large waterfront land on Long Lake.Nice Waterfront.Many Possibilities.79 Acres
#
#
# 	Row: 32
# 		Number of rooms: None
#             	Number of bedrooms: None
#             	Number of bathrooms: None
# 		Year built: None
#             	Potential gross revenue: None
#             	Zoning: Resort, Residential, Recreational and tourism
#             	Additional features: Located on a lake
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 1,854,026 sqft
#
# 		Description: Large Waterfront Property On Long Lake.Good Waterfront.Many Possibilities 43 Acres
#
#
# 	Row: 33
# 		Number of rooms: None
#             	Number of bedrooms: None
#             	Number of bathrooms: None
# 		Year built: None
#             	Potential gross revenue: None
#             	Zoning: Residential
#             	Additional features: Located on a lake, Non-navigable body of water
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 5,880,600 sqft
#
# 		Description: Votre coin de paradis en pleine nature! Superbe terre boisée avec un chemin d'aménagé donnant accès a un lac tout au fond de la terre, vous recherchez votre havre de paix loin de tout? le voici!
#
#
# 	Row: 34
# 		Number of rooms: None
#             	Number of bedrooms: None
#             	Number of bathrooms: None
# 		Year built: None
#             	Potential gross revenue: None
#             	Zoning: Residential
#             	Additional features: Located on a lake, Navigable body of water, Non-navigable body of water
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 4,173,334 sqft
#
# 		Description: Terrain de plus de 95 acres (ancienne sablière) vous offrant un lac privé (lac sans bateau moteur) et aussi un accès au Grand Lac Noir (navigable bateaux moteurs). Ideal pour en faire soit un domaine privé ou pour un projet domiciliaire. À 1h20 de Montréal, 50 min de Laval, 15 minutes du Mont Morin-Heights, 30 minutes de Saint-Sauveur.
#
#
# 	Row: 35
# 		Number of rooms: None
#             	Number of bedrooms: None
#             	Number of bathrooms: None
# 		Year built: None
#             	Potential gross revenue: None
#             	Zoning: Residential
#             	Additional features: Located on a lake, Navigable body of water, Non-navigable body of water
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 3,913,538 sqft
#
# 		Description: Land of more than 89 acres (old sand pit) offering you a private lake (lake without motor boats) and also access to Grand Lac Noir (navigable motor boats). Ideal to create your very  own  private domain or for a housing project. It could be sold with another lot to maximize the frontage on the street # 15176493.
# 	Row: 36
# 		Number of rooms: 17 rooms
#             	Number of bedrooms: 3 bedrooms
#             	Number of bathrooms: 1 bathroom and 2 powder rooms
# 		Year built: Unknown age
#             	Potential gross revenue: None
#             	Zoning: None
#             	Additional features: Located on a pond, Basement 6 feet or +
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 4,057,990 sqft
#
# 		Description: Fermette 93 acres, érablière(non-exploitée), prairie,  boisé. Ecurie avec 8 boxs et 2° pour entreposage. Garage pour machinerie. Maison plein sud en façade, ensoleillée, solarium avec SPA, belle fenestration, vue panoramique. Garage attaché. Lac artificiel et 3 ruisseaux. Situé dans cul-de-sac. La campagne à 12 min. de Sherbrooke et des services.
#
#
# 	Row: 37
# 		Number of rooms: 8 rooms
#             	Number of bedrooms: 3 bedrooms
#             	Number of bathrooms: 1 bathroom
# 		Year built: 1989
#             	Potential gross revenue: None
#             	Zoning: None
#             	Additional features: Located on a river, Basement 6 feet or +
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 4,034,006 sqft
#
# 		Description: Fermette plain-pied avec 3 chambres à coucher au rez-de-chaussée, située sur une terre de plus de 109 arpents comprenant une grange de 100'1X27'11, des terres cultivables et une érablière de plus de 2000 entailles avec cabane à sucre. Terre bordée en partie par la rivière L'Assomption. Accès facile à l'autoroute 40 et à environ 35 min. de Montréal
#
#
# 	Row: 38
# 		Number of rooms: None
#             	Number of bedrooms: None
#             	Number of bathrooms: None
# 		Year built: None
#             	Potential gross revenue: None
#             	Zoning: Residential
#             	Additional features: Located on a lake, Non-navigable body of water
#             	Use of property: None
#             	Building area (at ground level): None
#             	Available area: None
#             	Lot area: 3,188,673 sqft
#
# 		Description: PINE HILL, Vaste domaine avec 4 terrains sur le bord d'un lac à truite, désservit par un chemin public. A une heure de Montréal. Idéal pour projet touristique, immobilier, possibilité de construire plusieurs maisons, centre récréatif etc. Très beaux projets possibles.  La TPS et TVQ sera appliquable sur 26 % de la vente.
#
#
# Stored 'df0' (DataFrame)
#       Category      Price  PPSF      PPSM                        Street  \
# 0          Lot   280000.0   NaN       NaN           Chemin  Édouard-Roy
# 1          Lot  1695000.0   NaN       NaN    108, Chemin de Gray Valley
# 2   Hobby farm  2399000.0   NaN       NaN            21, Rang des Vents
# 3          Lot        NaN   NaN  399900.0             60, Chemin  Grant
# 4      Cottage  1749000.0   NaN       NaN       117, Chemin des Érables
# 5   Hobby farm   199000.0   NaN       NaN         30, Chemin du Portage
# 6          Lot   689000.0   NaN       NaN           Côte des Intrépides
# 7         Land   650000.0   NaN       NaN         Chemin  Saint-Cyr Sud
# 8         Land  3200000.0   NaN       NaN                    Route  148
# 9         Land   139000.0   NaN       NaN         Chemin  Owl's Landing
# 10  Hobby farm   749000.0   NaN       NaN          205Z, Chemin  Brochu
# 11         Lot   250000.0   NaN       NaN          Chemin de la Martine
# 12        Land   324900.0   NaN       NaN                 2200, 6e Rang
# 13        Land  1400000.0   NaN       NaN                Lac à la Carpe
# 14         Lot  3250000.0   NaN       NaN          Chemin des Outaouais
# 15     Cottage   299000.0   NaN       NaN             1091Z, Route  263
# 16         Lot   349900.0   NaN       NaN             Chemin de l'Eider
# 17     Cottage   794000.0   NaN       NaN        1521Z, Chemin des Pins
# 18        Land  1500000.0   NaN       NaN                 Montée  Brien
# 19         Lot   350000.0   NaN       NaN              Route du Village
# 20         Lot  1125000.0   NaN       NaN          Chemin du Lac-Macaza
# 21        Land   895000.0   NaN       NaN     Chemin des 5e-et-6e-Rangs
# 22        Land   649000.0   NaN       NaN                       4e Rang
# 23        Land   599000.0   NaN       NaN          351, Route  Rousseau
# 24        Land   499000.0   NaN       NaN                       9e Rang
# 25         Lot   699000.0   NaN       NaN                        Rang 2
# 26  Hobby farm  2495000.0   NaN       NaN     2 - 9, Chemin de la Forge
# 27        Land  1200000.0   NaN       NaN          Rue  Olivier-Guimond
# 28         Lot   125000.0   NaN       NaN         Chemin du Lac-Francis
# 29  Hobby farm  1100000.0   NaN       NaN        2050, Chemin  Hamilton
# 30         Lot  3599000.0   NaN       NaN        Route  Jacques-Cartier
# 31        Land   130000.0   NaN       NaN            Chemin du Lac-Long
# 32        Land   160000.0   NaN       NaN            Chemin du Lac-Long
# 33        Land   300000.0   NaN       NaN             Chemin du 7e-Rang
# 34         Lot  1250000.0   NaN       NaN      Rue  Antoinette-Charland
# 35         Lot  1195000.0   NaN       NaN                Rue du Domaine
# 36  Hobby farm   789000.0   NaN       NaN         26Z, Chemin  Loiselle
# 37  Hobby farm   899000.0   NaN       NaN  284, Chemin  Cyrille-Beaudry
# 38         Lot   495000.0   NaN       NaN                   Rue  Bigras
#
#                                                  City  \
# 0   Sherbrooke (Brompton/Rock Forest/Saint-Élie/De...
# 1                                           Huberdeau
# 2                                             Brébeuf
# 3                                           Bouchette
# 4                                        Frelighsburg
# 5                                        Rivière-Héva
# 6                                      Mont-Tremblant
# 7                                      Wentworth-Nord
# 8                                           Grenville
# 9                               L'Isle-aux-Allumettes
# 10                                    Cookshire-Eaton
# 11                      Petite-Rivière-Saint-François
# 12                                      Saint-Calixte
# 13                                       Mont-Laurier
# 14                                     Pointe-Fortune
# 15                           Sainte-Cécile-de-Whitton
# 16                            Saint-Faustin/Lac-Carré
# 17                                     Trois-Rivières
# 18                                      Lac-Supérieur
# 19                                     Rapide-Danseur
# 20                                          La Macaza
# 21                                         Lac-Saguay
# 22                                       Saint-Damien
# 23                            Notre-Dame-de-Montauban
# 24                                         Saint-Côme
# 25                                          Lac-Simon
# 26                                              Ripon
# 27                                     Pointe-Fortune
# 28                             Notre-Dame-de-Pontmain
# 29                                          Inverness
# 30                                          Sept-Îles
# 31                                           Blue Sea
# 32                                           Blue Sea
# 33                                          La Macaza
# 34                                     Wentworth-Nord
# 35                                     Wentworth-Nord
# 36                                           Westbury
# 37                                         Saint-Paul
# 38                                 Brownsburg-Chatham
#
#                                                   URL     Rooms  \
# 0   https://www.centris.ca/en/lots~for-sale~sherbr...       NaN
# 1   https://www.centris.ca/en/lots~for-sale~huberd...       NaN
# 2   https://www.centris.ca/en/hobby-farms~for-sale...  12 rooms
# 3   https://www.centris.ca/en/lots~for-sale~bouche...      None
# 4   https://www.centris.ca/en/cottages~for-sale~fr...  13 rooms
# 5   https://www.centris.ca/en/hobby-farms~for-sale...  10 rooms
# 6   https://www.centris.ca/en/lots~for-sale~mont-t...      None
# 7   https://www.centris.ca/en/land~for-sale~wentwo...      None
# 8   https://www.centris.ca/en/land~for-sale~grenvi...      None
# 9   https://www.centris.ca/en/land~for-sale~l-isle...      None
# 10  https://www.centris.ca/en/hobby-farms~for-sale...  13 rooms
# 11  https://www.centris.ca/en/lots~for-sale~petite...      None
# 12  https://www.centris.ca/en/land~for-sale~saint-...      None
# 13  https://www.centris.ca/en/land~for-sale~mont-l...      None
# 14  https://www.centris.ca/en/lots~for-sale~pointe...      None
# 15  https://www.centris.ca/en/cottages~for-sale~sa...  11 rooms
# 16  https://www.centris.ca/en/lots~for-sale~saint-...      None
# 17  https://www.centris.ca/en/cottages~for-sale~tr...   3 rooms
# 18  https://www.centris.ca/en/land~for-sale~lac-su...      None
# 19  https://www.centris.ca/en/lots~for-sale~rapide...      None
# 20  https://www.centris.ca/en/lots~for-sale~la-mac...      None
# 21  https://www.centris.ca/en/land~for-sale~lac-sa...      None
# 22  https://www.centris.ca/en/land~for-sale~saint-...      None
# 23  https://www.centris.ca/en/land~for-sale~notre-...      None
# 24  https://www.centris.ca/en/land~for-sale~saint-...      None
# 25  https://www.centris.ca/en/lots~for-sale~lac-si...      None
# 26  https://www.centris.ca/en/hobby-farms~for-sale...  50 rooms
# 27  https://www.centris.ca/en/land~for-sale~pointe...      None
# 28  https://www.centris.ca/en/lots~for-sale~notre-...      None
# 29  https://www.centris.ca/en/hobby-farms~for-sale...  10 rooms
# 30  https://www.centris.ca/en/lots~for-sale~sept-i...      None
# 31  https://www.centris.ca/en/land~for-sale~blue-s...      None
# 32  https://www.centris.ca/en/land~for-sale~blue-s...      None
# 33  https://www.centris.ca/en/land~for-sale~la-mac...      None
# 34  https://www.centris.ca/en/lots~for-sale~wentwo...      None
# 35  https://www.centris.ca/en/lots~for-sale~wentwo...      None
# 36  https://www.centris.ca/en/hobby-farms~for-sale...  17 rooms
# 37  https://www.centris.ca/en/hobby-farms~for-sale...   8 rooms
# 38  https://www.centris.ca/en/lots~for-sale~browns...      None
#
#                       Bedrooms                       Bathrooms  \
# 0                          NaN                             NaN
# 1                          NaN                             NaN
# 2                   3 bedrooms                     4 bathrooms
# 3                         None                            None
# 4                   3 bedrooms   2 bathrooms and 1 powder room
# 5                   2 bedrooms                      1 bathroom
# 6                         None                            None
# 7                         None                            None
# 8                         None                            None
# 9                         None                            None
# 10                  4 bedrooms                     2 bathrooms
# 11                        None                            None
# 12                        None                            None
# 13                        None                            None
# 14                        None                            None
# 15                  3 bedrooms    1 bathroom and 1 powder room
# 16                        None                            None
# 17                        None                            None
# 18                        None                            None
# 19                        None                            None
# 20                        None                            None
# 21                        None                            None
# 22                        None                            None
# 23                        None                            None
# 24                        None                            None
# 25                        None                            None
# 26  9 bedrooms (1 in basement)  7 bathrooms and 2 powder rooms
# 27                        None                            None
# 28                        None                            None
# 29                  4 bedrooms                     2 bathrooms
# 30                        None                            None
# 31                        None                            None
# 32                        None                            None
# 33                        None                            None
# 34                        None                            None
# 35                        None                            None
# 36                  3 bedrooms   1 bathroom and 2 powder rooms
# 37                  3 bedrooms                      1 bathroom
# 38                        None                            None
#
#             Lot area   Year built  \
# 0     1,873,080 sqft          NaN
# 1     8,668,431 sqft          NaN
# 2     3,907,403 sqft  Unknown age
# 3     1,374,299 sqft         None
# 4     2,073,456 sqft  Unknown age
# 5     6,048,135 sqft         1954
# 6     4,530,240 sqft         None
# 7     2,743,914 sqft         None
# 8    12,022,560 sqft         None
# 9     3,049,200 sqft         None
# 10    4,198,707 sqft  Unknown age
# 11    1,913,791 sqft         None
# 12    3,354,571 sqft         None
# 13   14,157,000 sqft         None
# 14    3,038,863 sqft         None
# 15    2,117,016 sqft         1908
# 16    1,512,344 sqft         None
# 17    5,127,931 sqft         1940
# 18   14,847,671 sqft         None
# 19    2,981,374 sqft         None
# 20    3,179,880 sqft         None
# 21   11,604,560 sqft         None
# 22    4,443,123 sqft         None
# 23    4,592,988 sqft         None
# 24    8,108,050 sqft         None
# 25    2,060,856 sqft         None
# 26   21,462,883 sqft         1996
# 27    1,679,765 sqft         None
# 28    4,479,304 sqft         None
# 29    4,859,989 sqft  Unknown age
# 30  133,104,149 sqft         None
# 31    3,409,301 sqft         None
# 32    1,854,026 sqft         None
# 33    5,880,600 sqft         None
# 34    4,173,334 sqft         None
# 35    3,913,538 sqft         None
# 36    4,057,990 sqft  Unknown age
# 37    4,034,006 sqft         1989
# 38    3,188,673 sqft         None
#
#                                   Additional features  \
# 0                                 Located on a stream
# 1     Located on a river, Non-navigable body of water
# 2                                  Located on a river
# 3          Located on a lake, Navigable body of water
# 4      Located on a pond, Non-navigable body of water
# 5                                  Located on a river
# 6   Resort, Located on a lake, Navigable body of w...
# 7      Located on a lake, Non-navigable body of water
# 8         Located on a river, Navigable body of water
# 9                                  Located on a river
# 10            Located on a pond, Basement 6 feet or +
# 11    Located on a river, Non-navigable body of water
# 12     Located on a pond, Non-navigable body of water
# 13                                  Located on a lake
# 14        Located on a river, Navigable body of water
# 15   Located on a stream, Non-navigable body of water
# 16     Located on a lake, Non-navigable body of water
# 17           Located on a river, Basement 6 feet or +
# 18     Located on a lake, Non-navigable body of water
# 19  Resort, Located on a river, Navigable body of ...
# 20  Resort, Located on a lake, Navigable body of w...
# 21     Located on a lake, Non-navigable body of water
# 22     Located on a lake, Non-navigable body of water
# 23  Resort, Located on a lake, Non-navigable body ...
# 24     Located on a lake, Non-navigable body of water
# 25         Located on a lake, Navigable body of water
# 26     Located on a pond, Non-navigable body of water
# 27                                  Located on a lake
# 28                                  Located on a lake
# 29            Located on a pond, Basement 6 feet or +
# 30  Located on a fleuve (river), Navigable body of...
# 31                                  Located on a lake
# 32                                  Located on a lake
# 33     Located on a lake, Non-navigable body of water
# 34  Located on a lake, Navigable body of water, No...
# 35  Located on a lake, Navigable body of water, No...
# 36            Located on a pond, Basement 6 feet or +
# 37           Located on a river, Basement 6 feet or +
# 38     Located on a lake, Non-navigable body of water
#
#     Potential gross revenue  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19                      NaN
# 20                      NaN
# 21                      NaN
# 22                      NaN
# 23                      NaN
# 24                      NaN
# 25                      NaN
# 26                      NaN
# 27                      NaN
# 28                      NaN
# 29                      NaN
# 30                      NaN
# 31                      NaN
# 32                      NaN
# 33                      NaN
# 34                      NaN
# 35                      NaN
# 36                      NaN
# 37                      NaN
# 38                      NaN
#
#                                                Zoning  \
# 0                                         Residential
# 1            Other, Forest, Residential, Agricultural
# 2                                                None
# 3                                         Residential
# 4                                                None
# 5                                                None
# 6                                 Resort, Residential
# 7                                         Residential
# 8               Recreational and tourism, Residential
# 9                                         Residential
# 10                                               None
# 11  Commercial, Forest, Residential, Recreational ...
# 12                                        Residential
# 13                                        Residential
# 14                                        Residential
# 15                                               None
# 16                                        Residential
# 17                                               None
# 18                                        Residential
# 19                                Residential, Resort
# 20                                        Residential
# 21                                        Residential
# 22                                        Residential
# 23                                        Residential
# 24      Resort, Recreational and tourism, Residential
# 25                                Resort, Residential
# 26                                               None
# 27                                        Residential
# 28                                        Residential
# 29                                               None
# 30                 Other, Resort, Residential, Forest
# 31      Resort, Residential, Recreational and tourism
# 32      Resort, Residential, Recreational and tourism
# 33                                        Residential
# 34                                        Residential
# 35                                        Residential
# 36                                               None
# 37                                               None
# 38                                        Residential
#
#                                           Description  Use of property  \
# 0   Rareté ,+- 43 acres situé à quelques minutes d...              NaN
# 1   GRAY VALLEY - Remarquable property of over 223...              NaN
# 2   Fully renovated, this unique contemporary farm...              NaN
# 3   A wonderful piece of land on the majestic 31 M...              NaN
# 4   Follow your dream, Country Home. Frelighsburg ...              NaN
# 5   Fermette de 138.8 acres, accès à la rivière Ca...              NaN
# 6   104 acres. 261.58 m of frontage on the edge of...              NaN
# 7   Magnificent 63-acre waterfront lot on the pres...              NaN
# 8   An exceptional 276-acre site awaits you to des...              NaN
# 9   70 Acres with 477 Feet of Waterfront on the Ot...              NaN
# 10               Lot du terrain seulement est taxable              NaN
# 11                                               None              NaN
# 12  « TERRE UNIQUE À SAINT-CALIXTE » 91 arpents de...              NaN
# 13  A absolutely amazing opportunity to create a p...              NaN
# 14  Four adjoining, WATERFRONT, RESIDENTIAL lands ...              NaN
# 15  Belle d'époque sur une terre de 48.6 acres. Te...              NaN
# 16  Magnifique terrain de 34 acres (1 511 796 pied...              NaN
# 17  Ce domaine comporte un terrain de 1 300 000 pi...              NaN
# 18  Investors, promoters or entrepreneurs ... Grea...              NaN
# 19                                               None              NaN
# 20  WATERFRONT! Magnificent Domaine wooded on Lake...              NaN
# 21  Devenez propriétaire de votre coin de pays à v...              NaN
# 22  Lake surrounded by crown land 1.2 km long. Lot...              NaN
# 23  Bord du lac ( privé) ce domaine de 106 acres p...              NaN
# 24  Terre avec lac à vendre, rare sur le marché. P...              NaN
# 25  Are you looking for nature and great outdoors?...              NaN
# 26  DOMAIN of over 492 acres with 5 properties, in...              NaN
# 27  Remarkable lot to be developed. There are thre...              NaN
# 28                                               None              NaN
# 29  Renowned strawberry and raspberry farm. Magnif...              NaN
# 30  3055 acres of flat land 20 minutes away frome ...              NaN
# 31  Large waterfront land on Long Lake.Nice Waterf...              NaN
# 32  Large Waterfront Property On Long Lake.Good Wa...              NaN
# 33  Votre coin de paradis en pleine nature! Superb...              NaN
# 34  Terrain de plus de 95 acres (ancienne sablière...              NaN
# 35  Land of more than 89 acres (old sand pit) offe...              NaN
# 36  Fermette 93 acres, érablière(non-exploitée), p...              NaN
# 37  Fermette plain-pied avec 3 chambres à coucher ...              NaN
# 38  PINE HILL, Vaste domaine avec 4 terrains sur l...              NaN
#
#     Available area  Building area (at ground level)
# 0              NaN                              NaN
# 1              NaN                              NaN
# 2              NaN                              NaN
# 3              NaN                              NaN
# 4              NaN                              NaN
# 5              NaN                              NaN
# 6              NaN                              NaN
# 7              NaN                              NaN
# 8              NaN                              NaN
# 9              NaN                              NaN
# 10             NaN                              NaN
# 11             NaN                              NaN
# 12             NaN                              NaN
# 13             NaN                              NaN
# 14             NaN                              NaN
# 15             NaN                              NaN
# 16             NaN                              NaN
# 17             NaN                              NaN
# 18             NaN                              NaN
# 19             NaN                              NaN
# 20             NaN                              NaN
# 21             NaN                              NaN
# 22             NaN                              NaN
# 23             NaN                              NaN
# 24             NaN                              NaN
# 25             NaN                              NaN
# 26             NaN                              NaN
# 27             NaN                              NaN
# 28             NaN                              NaN
# 29             NaN                              NaN
# 30             NaN                              NaN
# 31             NaN                              NaN
# 32             NaN                              NaN
# 33             NaN                              NaN
# 34             NaN                              NaN
# 35             NaN                              NaN
# 36             NaN                              NaN
# 37             NaN                              NaN
# 38             NaN                              NaN
